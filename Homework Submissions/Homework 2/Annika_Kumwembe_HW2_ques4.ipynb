# %%
import numpy as np
import mpmath
import matplotlib.pyplot as plt
from matplotlib import animation

frame_num = len(r)  #sets the number of frames to be the length of the array for 'r' 
anim = animation.FuncAnimation(fig, drawframe, frames=frame_num, interval=500)#blit=True) 

from IPython.display import HTML #only necessary to display the video in-line in jupyer notebook
#This animation does not work in my notebook, or at least I'm not seeing it
#I have interesting values for x, it doesn't give me this sin shape, but it may have given me something in between

# %%
import numpy as np
import mpmath
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

def model(x, k):
    return np.sin(x) * np.cos(x) - k

x = np.linspace(-20, 35, 80)

fig, ax = plt.subplots(figsize = (10, 8))
plot = ax.plot(x, model(x, 0))

ax.set_xlabel('phi')
ax.set_ylabel('phi dot')
ax.set_title('phi dot changing with k')
ax.grid(True)

ax.set_xlim(-10, 10)
ax.set_ylim(-.51, .51)

def animation(k):
    line.set_ydata(model(x, k))
    return plot
ani = FuncAnimation(fig, animation, frames=np.linspace(0, 2*np.pi, 100), interval=50, blit=True)

plt.show()

#I have been trying to get the animation to actually 'animate', but I don't think I'll be able to for this one
