# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from matplotlib.animation import FuncAnimation

# %%
#Define Constant
l = 2
#x = phi
#Function for 1D Flow
def Function(x,k):
    Equation = l * np.sin(x) * (np.cos(x) - k)
    return Equation

#Values for x (x = phi)
x_values = np.linspace(-10,10,400)

#find k<1 and k>1

#plotting Magic
fig, ax = plt.subplots()
plot = ax.plot(x_values, Function(x_values,k))
ax.set_xlim(-3.5,3.5)
ax.set_xlabel('phi')
ax.set_ylabel('f(phi)')
ax.set_title('flow of k')

def Animate(frame):
    k = 1.5 + frame * 0.01
    line.set_ydata(Function(x,k))
    return line

ani = FuncAnimation(fig, Animate, franes=np.arrange(0, 100), blit = true, interval = 100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 27
#      24     line.set_ydata(Function(x,k))
#      25     return line
# ---> 27 ani = FuncAnimation(fig, Animate, franes=np.arrange(0, 100), blit = true, interval = 100)
#      28 plt.show()
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrange'
