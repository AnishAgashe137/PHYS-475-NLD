# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
# function that returns dx/dt
def model(x0,t):
    dxdt = np.sin(x)
    return dxdt

#def Invert_Model(x0,t):
#    dxdt = 2 * np.arctan((np.exp(t)) / (np.csc(x0) + np.cot(x0)))
#    return dxdt
# np doesn't have access to csc and cot for some reason?

def Invert_Model(x0,t):
    dxdt = 2 * np.arctan(np.exp(t) / (1/np.sin(x0)) + ((np.cos(x0))/(np.sin(x0))))
    return dxdt

# initial condition
x_Int = [np.pi / 4, np.pi/2, (7 * np.pi) / 4]

# time points
t = np.linspace(0,5)

#Plotting Magic
for x0 in x_Int:
    Steps = Invert_Model(x0,t)
    plt.plot(t,Steps)

# How does Labeling work in graphing? Only getting erroros or printing plaintex when i try to use label also not sure why  its printing 0, 0.5, and x(t)

#Plot Setup
plt.xlabel('Time')
plt.ylabel('x(t)')
# Out:
# Text(0, 0.5, 'x(t)')
